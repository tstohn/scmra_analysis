# %%
#generate data do compare network quality
#safe average differences between wt and mut population
import sys
sys.path.insert(0, '../../helperScripts/')
from helperFunctions import *
import scmra
import os
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import math
import pandas as pd
from datetime import datetime
import pickle
import seaborn as sns; sns.set_theme()
from matplotlib.pyplot import figure
import scmra

# %%
def get_population_list_from_string(string):
   popList = []
   x = string.split(",")
   for pop in x:
      if pop == "": 
         continue
      else:
         popList.append(pop)
   return(popList)

def calculate_diff_dict():
   dict = {}
   dict['braf'] = ((rloc_true - rloc_braf)**2)**0.5
   dict['ras'] = ((rloc_true - rloc_ras)**2)**0.5

   return(dict)

def extract_average_rloc_differences(pickleFile, outputFile,):
   result = pickle.load(open(pickleFile, 'rb'))

   diffDict = calculate_diff_dict()

   # Create the pandas DataFrame
   df = pd.DataFrame(columns=["POPULATIONS", "rloc", "value"] + result.header)
   
   # for every combination of
   # NOISE CELLNUM REPEAT of CNR
   headers = result.header
   resultFrame = pd.DataFrame(columns=headers)
   #add all the existing parameters
   resultNumber = len(result.parameter)
   for i in range(resultNumber):
      params = result.parameter[i]
      df_length = len(resultFrame)
      resultFrame.loc[df_length] = params
   cnrData = resultFrame[resultFrame["MODELTYPE"] == "CNR"]

   #get noise cellnum and repeats for CNR
   noiseLevels = cnrData["NOISE"].unique()
   cellnumLevels = cnrData["CELLNUM"].unique()
   repeatLevels = cnrData["REPEAT"].unique()
   thetaLevels = cnrData["THETA"].unique()

   #get populations that r compared for CNR (taking only the ones with 2 populations for now)
   populationLevelsTmp = cnrData["POPULATIONS"].unique()
   populationLevels = []
   for level in populationLevelsTmp:
      x = level.split(",")
      populationNumber = 0
      for pop in x:
         if pop == "": continue
         populationNumber += 1

      if(populationNumber == 2):
         populationLevels.append(level)

   #---------------------------
   #CNR
   #---------------------------
   keyList = ["MODELTYPE", "NOISE", "CELLNUM", "POPULATIONS","REPEAT","THETA","EDGES"]
   for noise in noiseLevels:
      for cellnum in cellnumLevels:
         for pop in populationLevels:
            for repeat in repeatLevels:
               for theta in thetaLevels:
                  valueList = ["CNR", noise, cellnum, pop, repeat, theta, 13]
                  popList = get_population_list_from_string(pop) # list of populations like ["wt", "braf"]
                  if(len(popList) != 2): 
                     print("NOT EXACTLY 2 POPULATIONS FOR MRA -> SKIP MRA RLOC DIFF CALCUALTION\n")
                     continue
                  if(not "wt" in popList and not "WT" in popList): 
                     print("NO wildtype <wt> in population list (needed for rloc Diff) -> SKIP MRA RLOC DIFF CALCUALTION \n")
                     continue

                  resultObject, params = result.getResult(keyList, valueList) #the result from the simulation
                  if(resultObject == None): continue

                  vars_lst = [var for var in resultObject.vardict if var.startswith('IDev')]
                  vars_vals = [resultObject.vardict[v] for v in vars_lst]
                  lengthIdcs = (np.count_nonzero(vars_vals))

                  assert(len(popList) == 2)
                  rloc_list = {}
                  #we assign population by wt, braf, ras. Those MUST BE LOWER CASE NAMES.
                  #just in case convert to lower case beforehand
                  lowerPopList = []
                  for popTmp in popList:
                     lowerPopList.append(popTmp.lower())
                  popList = lowerPopList
                  for popStringIdx in range(len(popList)):
                     popString = popList[popStringIdx]
                     rloc_tmp = resultObject.rloc[popString]
                     rloc_tmp = reorder_rloc(rloc_tmp)
                     rloc_list[popList[popStringIdx]] = (rloc_tmp)

                  # get all rloc differences and write one line per difference
                  columns = (rloc_true.columns)
                  rows = (rloc_true.index)

                  if("braf" in popList):
                     reconstuctedDiff = rloc_list["braf"] - rloc_list["wt"]
                  elif("ras" in popList):
                     reconstuctedDiff = rloc_list["ras"] - rloc_list["wt"]
                  
                  for col in columns:
                     for row in rows:
                        #difference is defined as mutant - wildtype
                        value = reconstuctedDiff.at[row, col]
                        rloc = row + "_" + col

                        #write new row in result data frame
                        # dataframe struture is: columns=["NOISE", "CELLNUM", "REPEAT", "POPULATIONS", "DIFFERENCE_RMSE"]
                        list1 = [str(popList[0]) + "_" + str(popList[1]), rloc, value]
                        list2 = params
                        rowList = [*list1, *list2] 
                        df.loc[len(df)] = rowList

   #---------------------------
   #MRA
   #---------------------------
   headers = result.header
   resultFrame = pd.DataFrame(columns=headers)
   #add all the existing parameters
   resultNumber = len(result.parameter)
   for i in range(resultNumber):
      params = result.parameter[i]
      df_length = len(resultFrame)
      resultFrame.loc[df_length] = params
   mraData = resultFrame[resultFrame["MODELTYPE"] == "MRA"]

   if(not mraData.empty):

      #get all possible populations to look into for MRA
      keyList = ["MODELTYPE", "NOISE", "CELLNUM", "POPULATIONS","REPEAT"]

      for popList in [ ["WT:wt_braf", "BRAF:wt_braf"], ["WT:wt_ras","RAS:wt_ras"]]:
         for repeatId in repeatLevels:
            for noise in noiseLevels:
               for cellnum in cellnumLevels:

                  #GET FIRST RESULT
                  valueList = ["MRA", noise, cellnum, popList[0], repeatId]
                  result1, params1 = result.getResult(keyList, valueList, False, True) #the result from the simulation

                  assert(len(result1) == 1)           
                  result1 = result1[0]
                  params1 = params1[0]
                  popListSingle = popList[0].split(":")
                  pop1 = popListSingle[0]
                  assert(pop1 == "WT")

                  #GET SECOND RESULT
                  valueList = ["MRA", noise, cellnum, popList[1], repeatId]
                  result2, params2 = result.getResult(keyList, valueList, False, True) #the result from the simulation
                  assert(len(result2) == 1)           
                  result2 = result2[0]
                  params2 = params2[0]
                  popListSingle = popList[1].split(":")
                  pop2 = popListSingle[0]
                  assert(pop2 == "BRAF" or pop2 == "RAS")

                  print(pop1)
                  print(pop2)

                  populationList = []

                  populationList.append(pop1.lower())
                  populationList.append(pop2.lower())
                  #calculate RMSE for ALL COMBINATIONS

                  rloc_list = {}
                  columns = (rloc_true.columns)
                  rows = (rloc_true.index)
                  rloc_tmp1 = reorder_rloc(result1.rloc)
                  rloc_tmp2 = reorder_rloc(result2.rloc)
                  rloc_list["wt"] = (rloc_tmp1)
                  if(pop2 == "BRAF"):
                     rloc_list["braf"] = (rloc_tmp2)
                     reconstuctedDiff = rloc_list["braf"] - rloc_list["wt"]
                  elif(pop2 == "RAS"):
                     rloc_list["ras"] = (rloc_tmp2)
                     reconstuctedDiff = rloc_list["ras"] - rloc_list["wt"]
                  
                  for col in columns:
                     for row in rows:
                        #difference is defined as mutant - wildtype
                        value = reconstuctedDiff.at[row, col]
                        rloc = row + "_" + col

                        #write new row in result data frame
                        # dataframe struture is: columns=["NOISE", "CELLNUM", "REPEAT", "POPULATIONS", "DIFFERENCE_RMSE"]
                        list1 = [str(pop1) + "_" + str(pop2), rloc, value]
                        list2 = params1
                        rowList = [*list1, *list2] 
                        df.loc[len(df)] = rowList

   #finally print the dataframe
   df.to_csv(outputFile, index=False, sep="\t")

# %%
pickleFile = "/DATA/t.stohn/MRA/scMRA-analysis/notebooks/paperAnalyses/2_CNRAnalysis/bin/SIMULATION_CnrOverMra_NoiseRange_CellNum250_04-19-2023|20:59:39.pickle"
result = pickle.load(open(pickleFile, 'rb'))

extract_average_rloc_differences(pickleFile, "./bin/AverageRlocDifference.txt")
# Out:
# WT
# BRAF
# ['WT_BRAF', 'Sos_Sos', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Ras_Sos', -0.012468785029130514, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Raf1_Sos', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Mek_Sos', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Erk_Sos', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'P90Rsk_Sos', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'PI3K_Sos', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Akt_Sos', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'C3G_Sos', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Rap1_Sos', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'bRaf_Sos', -0.16560820564027254, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Sos_Ras', 0.007271263540411188, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Ras_Ras', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Raf1_Ras', 0.006307548119098505, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Mek_Ras', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Erk_Ras', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'P90Rsk_Ras', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'PI3K_Ras', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Akt_Ras', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'C3G_Ras', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Rap1_Ras', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'bRaf_Ras', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Sos_Raf1', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Ras_Raf1', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Raf1_Raf1', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Mek_Raf1', -0.08179797432005839, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Erk_Raf1', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'P90Rsk_Raf1', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'PI3K_Raf1', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Akt_Raf1', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'C3G_Raf1', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Rap1_Raf1', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'bRaf_Raf1', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Sos_Mek', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Ras_Mek', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Raf1_Mek', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Mek_Mek', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Erk_Mek', -0.94547732606833, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'P90Rsk_Mek', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'PI3K_Mek', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Akt_Mek', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'C3G_Mek', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Rap1_Mek', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'bRaf_Mek', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Sos_Erk', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Ras_Erk', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Raf1_Erk', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Mek_Erk', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Erk_Erk', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'P90Rsk_Erk', -0.7228661791533524, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'PI3K_Erk', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Akt_Erk', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'C3G_Erk', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Rap1_Erk', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'bRaf_Erk', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Sos_P90Rsk', -0.12465206528271366, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Ras_P90Rsk', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Raf1_P90Rsk', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Mek_P90Rsk', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Erk_P90Rsk', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'P90Rsk_P90Rsk', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'PI3K_P90Rsk', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Akt_P90Rsk', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'C3G_P90Rsk', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Rap1_P90Rsk', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'bRaf_P90Rsk', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Sos_PI3K', 0.024299726423187246, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Ras_PI3K', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Raf1_PI3K', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Mek_PI3K', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Erk_PI3K', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'P90Rsk_PI3K', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'PI3K_PI3K', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Akt_PI3K', -0.008536883971327291, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'C3G_PI3K', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Rap1_PI3K', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'bRaf_PI3K', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Sos_Akt', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Ras_Akt', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Raf1_Akt', 0.021062583307508154, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Mek_Akt', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Erk_Akt', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'P90Rsk_Akt', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'PI3K_Akt', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Akt_Akt', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'C3G_Akt', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Rap1_Akt', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'bRaf_Akt', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Sos_C3G', 0.01990249620493965, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Ras_C3G', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Raf1_C3G', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Mek_C3G', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Erk_C3G', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'P90Rsk_C3G', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'PI3K_C3G', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Akt_C3G', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'C3G_C3G', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Rap1_C3G', -0.012522098211018795, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'bRaf_C3G', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Sos_Rap1', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Ras_Rap1', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Raf1_Rap1', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Mek_Rap1', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Erk_Rap1', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'P90Rsk_Rap1', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'PI3K_Rap1', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Akt_Rap1', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'C3G_Rap1', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Rap1_Rap1', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'bRaf_Rap1', -0.3335743610787818, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Sos_bRaf', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Ras_bRaf', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Raf1_bRaf', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Mek_bRaf', -0.8200636627672835, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Erk_bRaf', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'P90Rsk_bRaf', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'PI3K_bRaf', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Akt_bRaf', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'C3G_bRaf', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'Rap1_bRaf', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# ['WT_BRAF', 'bRaf_bRaf', 0.0, 0.0, 250, 0.00625, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 6.14997963409419e-05]
# WT
# BRAF
# ['WT_BRAF', 'Sos_Sos', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Ras_Sos', -0.1974499435144108, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Raf1_Sos', -0.010654485890504883, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Mek_Sos', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Erk_Sos', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'P90Rsk_Sos', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'PI3K_Sos', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Akt_Sos', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'C3G_Sos', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Rap1_Sos', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'bRaf_Sos', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Sos_Ras', 0.018171706546341204, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Ras_Ras', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Raf1_Ras', 0.018877783659187686, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Mek_Ras', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Erk_Ras', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'P90Rsk_Ras', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'PI3K_Ras', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Akt_Ras', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'C3G_Ras', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Rap1_Ras', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'bRaf_Ras', -0.16578706512079067, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Sos_Raf1', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Ras_Raf1', 0.24932397629342498, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Raf1_Raf1', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Mek_Raf1', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Erk_Raf1', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'P90Rsk_Raf1', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'PI3K_Raf1', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Akt_Raf1', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'C3G_Raf1', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Rap1_Raf1', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'bRaf_Raf1', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Sos_Mek', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Ras_Mek', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Raf1_Mek', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Mek_Mek', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Erk_Mek', -0.9043002088801632, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'P90Rsk_Mek', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'PI3K_Mek', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Akt_Mek', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'C3G_Mek', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Rap1_Mek', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'bRaf_Mek', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Sos_Erk', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Ras_Erk', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Raf1_Erk', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Mek_Erk', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Erk_Erk', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'P90Rsk_Erk', -0.6665310261365729, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'PI3K_Erk', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Akt_Erk', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'C3G_Erk', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Rap1_Erk', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'bRaf_Erk', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Sos_P90Rsk', -0.06103586420140389, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Ras_P90Rsk', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Raf1_P90Rsk', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Mek_P90Rsk', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Erk_P90Rsk', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'P90Rsk_P90Rsk', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'PI3K_P90Rsk', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Akt_P90Rsk', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'C3G_P90Rsk', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Rap1_P90Rsk', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'bRaf_P90Rsk', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Sos_PI3K', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Ras_PI3K', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Raf1_PI3K', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Mek_PI3K', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Erk_PI3K', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'P90Rsk_PI3K', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'PI3K_PI3K', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Akt_PI3K', -0.010100052026466078, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'C3G_PI3K', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Rap1_PI3K', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'bRaf_PI3K', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Sos_Akt', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Ras_Akt', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Raf1_Akt', -0.0014542808911607863, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Mek_Akt', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Erk_Akt', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'P90Rsk_Akt', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'PI3K_Akt', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Akt_Akt', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'C3G_Akt', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Rap1_Akt', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'bRaf_Akt', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Sos_C3G', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Ras_C3G', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Raf1_C3G', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Mek_C3G', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Erk_C3G', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'P90Rsk_C3G', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'PI3K_C3G', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Akt_C3G', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'C3G_C3G', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Rap1_C3G', -0.009674752154634203, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'bRaf_C3G', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Sos_Rap1', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Ras_Rap1', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Raf1_Rap1', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Mek_Rap1', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Erk_Rap1', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'P90Rsk_Rap1', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'PI3K_Rap1', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Akt_Rap1', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'C3G_Rap1', 0.3121779621299676, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Rap1_Rap1', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'bRaf_Rap1', -0.3320058865766376, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Sos_bRaf', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Ras_bRaf', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Raf1_bRaf', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Mek_bRaf', -0.7694492015012104, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Erk_bRaf', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'P90Rsk_bRaf', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'PI3K_bRaf', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Akt_bRaf', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'C3G_bRaf', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'Rap1_bRaf', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# ['WT_BRAF', 'bRaf_bRaf', 0.0, 0.2, 250, 0.025, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.0010587681757732587]
# WT
# BRAF
# ['WT_BRAF', 'Sos_Sos', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Ras_Sos', -0.03798161175060344, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Raf1_Sos', -0.06003469744308526, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Mek_Sos', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Erk_Sos', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'P90Rsk_Sos', -0.15332445765968009, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'PI3K_Sos', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Akt_Sos', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'C3G_Sos', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Rap1_Sos', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'bRaf_Sos', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Sos_Ras', 0.0030085243287036323, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Ras_Ras', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Raf1_Ras', 0.11178348608903638, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Mek_Ras', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Erk_Ras', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'P90Rsk_Ras', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'PI3K_Ras', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Akt_Ras', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'C3G_Ras', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Rap1_Ras', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'bRaf_Ras', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Sos_Raf1', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Ras_Raf1', -0.05180996353135858, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Raf1_Raf1', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Mek_Raf1', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Erk_Raf1', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'P90Rsk_Raf1', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'PI3K_Raf1', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Akt_Raf1', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'C3G_Raf1', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Rap1_Raf1', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'bRaf_Raf1', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Sos_Mek', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Ras_Mek', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Raf1_Mek', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Mek_Mek', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Erk_Mek', -0.7297771817548656, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'P90Rsk_Mek', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'PI3K_Mek', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Akt_Mek', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'C3G_Mek', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Rap1_Mek', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'bRaf_Mek', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Sos_Erk', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Ras_Erk', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Raf1_Erk', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Mek_Erk', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Erk_Erk', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'P90Rsk_Erk', -0.46926138123939787, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'PI3K_Erk', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Akt_Erk', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'C3G_Erk', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Rap1_Erk', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'bRaf_Erk', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Sos_P90Rsk', -0.136127917712014, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Ras_P90Rsk', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Raf1_P90Rsk', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Mek_P90Rsk', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Erk_P90Rsk', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'P90Rsk_P90Rsk', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'PI3K_P90Rsk', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Akt_P90Rsk', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'C3G_P90Rsk', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Rap1_P90Rsk', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'bRaf_P90Rsk', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Sos_PI3K', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Ras_PI3K', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Raf1_PI3K', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Mek_PI3K', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Erk_PI3K', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'P90Rsk_PI3K', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'PI3K_PI3K', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Akt_PI3K', 0.005867523071390712, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'C3G_PI3K', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Rap1_PI3K', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'bRaf_PI3K', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Sos_Akt', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Ras_Akt', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Raf1_Akt', 0.030240159671726385, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Mek_Akt', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Erk_Akt', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'P90Rsk_Akt', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'PI3K_Akt', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Akt_Akt', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'C3G_Akt', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Rap1_Akt', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'bRaf_Akt', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Sos_C3G', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Ras_C3G', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Raf1_C3G', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Mek_C3G', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Erk_C3G', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'P90Rsk_C3G', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'PI3K_C3G', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Akt_C3G', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'C3G_C3G', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Rap1_C3G', -0.09592110038520152, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'bRaf_C3G', -0.6254463372059971, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Sos_Rap1', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Ras_Rap1', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Raf1_Rap1', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Mek_Rap1', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Erk_Rap1', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'P90Rsk_Rap1', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'PI3K_Rap1', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Akt_Rap1', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'C3G_Rap1', 0.292081238646931, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Rap1_Rap1', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'bRaf_Rap1', 0.5272923677403752, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Sos_bRaf', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Ras_bRaf', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Raf1_bRaf', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Mek_bRaf', -0.7045125742678454, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Erk_bRaf', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'P90Rsk_bRaf', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'PI3K_bRaf', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Akt_bRaf', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'C3G_bRaf', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'Rap1_bRaf', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# ['WT_BRAF', 'bRaf_bRaf', 0.0, 0.5, 250, 0.1, 0, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 0.005677367256630838]
# WT
# BRAF
# ['WT_BRAF', 'Sos_Sos', 0.0, 0.0, 250, 0.00625, 1, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 8.309401389973778e-05]
# ['WT_BRAF', 'Ras_Sos', -0.07236058621547636, 0.0, 250, 0.00625, 1, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 8.309401389973778e-05]
# ['WT_BRAF', 'Raf1_Sos', 0.0, 0.0, 250, 0.00625, 1, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 8.309401389973778e-05]
# ['WT_BRAF', 'Mek_Sos', 0.0, 0.0, 250, 0.00625, 1, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 8.309401389973778e-05]
# ['WT_BRAF', 'Erk_Sos', 0.0, 0.0, 250, 0.00625, 1, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 8.309401389973778e-05]
# ['WT_BRAF', 'P90Rsk_Sos', 0.0, 0.0, 250, 0.00625, 1, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 8.309401389973778e-05]
# ['WT_BRAF', 'PI3K_Sos', 0.0, 0.0, 250, 0.00625, 1, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 8.309401389973778e-05]
# ['WT_BRAF', 'Akt_Sos', 0.0, 0.0, 250, 0.00625, 1, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 8.309401389973778e-05]
# ['WT_BRAF', 'C3G_Sos', 0.0, 0.0, 250, 0.00625, 1, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 8.309401389973778e-05]
# ['WT_BRAF', 'Rap1_Sos', 0.0, 0.0, 250, 0.00625, 1, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 8.309401389973778e-05]
# ['WT_BRAF', 'bRaf_Sos', 0.0, 0.0, 250, 0.00625, 1, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 8.309401389973778e-05]
# ['WT_BRAF', 'Sos_Ras', 0.11164182782652443, 0.0, 250, 0.00625, 1, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 8.309401389973778e-05]
# ['WT_BRAF', 'Ras_Ras', 0.0, 0.0, 250, 0.00625, 1, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 8.309401389973778e-05]
# ['WT_BRAF', 'Raf1_Ras', 0.006891166893108314, 0.0, 250, 0.00625, 1, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 8.309401389973778e-05]
# ['WT_BRAF', 'Mek_Ras', 0.0, 0.0, 250, 0.00625, 1, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 8.309401389973778e-05]
# ['WT_BRAF', 'Erk_Ras', 0.0, 0.0, 250, 0.00625, 1, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 8.309401389973778e-05]
# ['WT_BRAF', 'P90Rsk_Ras', 0.0, 0.0, 250, 0.00625, 1, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 8.309401389973778e-05]
# ['WT_BRAF', 'PI3K_Ras', 0.0, 0.0, 250, 0.00625, 1, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 8.309401389973778e-05]
# ['WT_BRAF', 'Akt_Ras', 0.0, 0.0, 250, 0.00625, 1, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 8.309401389973778e-05]
# ['WT_BRAF', 'C3G_Ras', 0.0, 0.0, 250, 0.00625, 1, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 8.309401389973778e-05]
# ['WT_BRAF', 'Rap1_Ras', 0.0, 0.0, 250, 0.00625, 1, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 8.309401389973778e-05]
# ['WT_BRAF', 'bRaf_Ras', -0.1730543035108151, 0.0, 250, 0.00625, 1, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 8.309401389973778e-05]
# ['WT_BRAF', 'Sos_Raf1', 0.0, 0.0, 250, 0.00625, 1, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 8.309401389973778e-05]
# ['WT_BRAF', 'Ras_Raf1', 0.09335371044598205, 0.0, 250, 0.00625, 1, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 8.309401389973778e-05]
# ['WT_BRAF', 'Raf1_Raf1', 0.0, 0.0, 250, 0.00625, 1, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 8.309401389973778e-05]
# ['WT_BRAF', 'Mek_Raf1', -0.07685490934673501, 0.0, 250, 0.00625, 1, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 8.309401389973778e-05]
# ['WT_BRAF', 'Erk_Raf1', 0.0, 0.0, 250, 0.00625, 1, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 8.309401389973778e-05]
# ['WT_BRAF', 'P90Rsk_Raf1', 0.0, 0.0, 250, 0.00625, 1, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 8.309401389973778e-05]
# ['WT_BRAF', 'PI3K_Raf1', 0.0, 0.0, 250, 0.00625, 1, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 8.309401389973778e-05]
# ['WT_BRAF', 'Akt_Raf1', 0.0, 0.0, 250, 0.00625, 1, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 8.309401389973778e-05]
# ['WT_BRAF', 'C3G_Raf1', 0.0, 0.0, 250, 0.00625, 1, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 8.309401389973778e-05]
# ['WT_BRAF', 'Rap1_Raf1', 0.0, 0.0, 250, 0.00625, 1, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 8.309401389973778e-05]
# ['WT_BRAF', 'bRaf_Raf1', 0.0, 0.0, 250, 0.00625, 1, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 8.309401389973778e-05]
# ['WT_BRAF', 'Sos_Mek', 0.0, 0.0, 250, 0.00625, 1, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 8.309401389973778e-05]
# ['WT_BRAF', 'Ras_Mek', 0.0, 0.0, 250, 0.00625, 1, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 8.309401389973778e-05]
# ['WT_BRAF', 'Raf1_Mek', 0.0, 0.0, 250, 0.00625, 1, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 8.309401389973778e-05]
# ['WT_BRAF', 'Mek_Mek', 0.0, 0.0, 250, 0.00625, 1, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 8.309401389973778e-05]
# ['WT_BRAF', 'Erk_Mek', -0.9476897628951264, 0.0, 250, 0.00625, 1, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 8.309401389973778e-05]
# ['WT_BRAF', 'P90Rsk_Mek', 0.0, 0.0, 250, 0.00625, 1, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 8.309401389973778e-05]
# ['WT_BRAF', 'PI3K_Mek', 0.0, 0.0, 250, 0.00625, 1, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 8.309401389973778e-05]
# ['WT_BRAF', 'Akt_Mek', 0.0, 0.0, 250, 0.00625, 1, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 8.309401389973778e-05]
# ['WT_BRAF', 'C3G_Mek', 0.0, 0.0, 250, 0.00625, 1, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 8.309401389973778e-05]
# ['WT_BRAF', 'Rap1_Mek', 0.0, 0.0, 250, 0.00625, 1, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 8.309401389973778e-05]
# ['WT_BRAF', 'bRaf_Mek', 0.0, 0.0, 250, 0.00625, 1, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 8.309401389973778e-05]
# ['WT_BRAF', 'Sos_Erk', 0.0, 0.0, 250, 0.00625, 1, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 8.309401389973778e-05]
# ['WT_BRAF', 'Ras_Erk', 0.0, 0.0, 250, 0.00625, 1, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 8.309401389973778e-05]
# ['WT_BRAF', 'Raf1_Erk', 0.0, 0.0, 250, 0.00625, 1, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 8.309401389973778e-05]
# ['WT_BRAF', 'Mek_Erk', 0.0, 0.0, 250, 0.00625, 1, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 8.309401389973778e-05]
# ['WT_BRAF', 'Erk_Erk', 0.0, 0.0, 250, 0.00625, 1, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 8.309401389973778e-05]
# ['WT_BRAF', 'P90Rsk_Erk', -0.7131653416314896, 0.0, 250, 0.00625, 1, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 8.309401389973778e-05]
# ['WT_BRAF', 'PI3K_Erk', 0.0, 0.0, 250, 0.00625, 1, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 8.309401389973778e-05]
# ['WT_BRAF', 'Akt_Erk', 0.0, 0.0, 250, 0.00625, 1, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 8.309401389973778e-05]
# ['WT_BRAF', 'C3G_Erk', 0.0, 0.0, 250, 0.00625, 1, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 8.309401389973778e-05]
# ['WT_BRAF', 'Rap1_Erk', 0.0, 0.0, 250, 0.00625, 1, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 8.309401389973778e-05]
# ['WT_BRAF', 'bRaf_Erk', 0.0, 0.0, 250, 0.00625, 1, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 8.309401389973778e-05]
# ['WT_BRAF', 'Sos_P90Rsk', 0.011941678257330834, 0.0, 250, 0.00625, 1, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 8.309401389973778e-05]
# ['WT_BRAF', 'Ras_P90Rsk', 0.0, 0.0, 250, 0.00625, 1, 13, 'MRA', 'WT:wt_braf', 0, 'NO_THETA', 8.309401389973778e-05]
# ...
# ['WT_RAS', 'Rap1_Rap1', 0.0, 0.2, 250, 0.025, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.0009716791119632344]
# ['WT_RAS', 'bRaf_Rap1', -0.8182561830126079, 0.2, 250, 0.025, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.0009716791119632344]
# ['WT_RAS', 'Sos_bRaf', 0.0, 0.2, 250, 0.025, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.0009716791119632344]
# ['WT_RAS', 'Ras_bRaf', 0.0, 0.2, 250, 0.025, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.0009716791119632344]
# ['WT_RAS', 'Raf1_bRaf', 0.0, 0.2, 250, 0.025, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.0009716791119632344]
# ['WT_RAS', 'Mek_bRaf', -0.23946101011342524, 0.2, 250, 0.025, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.0009716791119632344]
# ['WT_RAS', 'Erk_bRaf', 0.0, 0.2, 250, 0.025, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.0009716791119632344]
# ['WT_RAS', 'P90Rsk_bRaf', 0.0, 0.2, 250, 0.025, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.0009716791119632344]
# ['WT_RAS', 'PI3K_bRaf', 0.0, 0.2, 250, 0.025, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.0009716791119632344]
# ['WT_RAS', 'Akt_bRaf', 0.0, 0.2, 250, 0.025, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.0009716791119632344]
# ['WT_RAS', 'C3G_bRaf', 0.0, 0.2, 250, 0.025, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.0009716791119632344]
# ['WT_RAS', 'Rap1_bRaf', 0.0, 0.2, 250, 0.025, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.0009716791119632344]
# ['WT_RAS', 'bRaf_bRaf', 0.0, 0.2, 250, 0.025, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.0009716791119632344]
# WT
# RAS
# ['WT_RAS', 'Sos_Sos', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Ras_Sos', -0.06786422701944234, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Raf1_Sos', -0.33672104955524645, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Mek_Sos', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Erk_Sos', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'P90Rsk_Sos', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'PI3K_Sos', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Akt_Sos', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'C3G_Sos', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Rap1_Sos', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'bRaf_Sos', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Sos_Ras', 0.10087131333010224, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Ras_Ras', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Raf1_Ras', 0.36813706393126083, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Mek_Ras', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Erk_Ras', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'P90Rsk_Ras', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'PI3K_Ras', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Akt_Ras', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'C3G_Ras', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Rap1_Ras', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'bRaf_Ras', 0.7152044417380735, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Sos_Raf1', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Ras_Raf1', -0.30038643689632966, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Raf1_Raf1', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Mek_Raf1', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Erk_Raf1', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'P90Rsk_Raf1', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'PI3K_Raf1', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Akt_Raf1', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'C3G_Raf1', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Rap1_Raf1', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'bRaf_Raf1', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Sos_Mek', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Ras_Mek', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Raf1_Mek', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Mek_Mek', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Erk_Mek', -0.1584195619504718, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'P90Rsk_Mek', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'PI3K_Mek', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Akt_Mek', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'C3G_Mek', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Rap1_Mek', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'bRaf_Mek', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Sos_Erk', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Ras_Erk', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Raf1_Erk', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Mek_Erk', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Erk_Erk', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'P90Rsk_Erk', -0.25726207427966297, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'PI3K_Erk', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Akt_Erk', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'C3G_Erk', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Rap1_Erk', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'bRaf_Erk', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Sos_P90Rsk', 0.25216620819869345, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Ras_P90Rsk', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Raf1_P90Rsk', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Mek_P90Rsk', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Erk_P90Rsk', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'P90Rsk_P90Rsk', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'PI3K_P90Rsk', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Akt_P90Rsk', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'C3G_P90Rsk', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Rap1_P90Rsk', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'bRaf_P90Rsk', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Sos_PI3K', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Ras_PI3K', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Raf1_PI3K', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Mek_PI3K', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Erk_PI3K', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'P90Rsk_PI3K', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'PI3K_PI3K', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Akt_PI3K', 0.09310110191567617, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'C3G_PI3K', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Rap1_PI3K', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'bRaf_PI3K', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Sos_Akt', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Ras_Akt', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Raf1_Akt', 0.0276938619916669, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Mek_Akt', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Erk_Akt', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'P90Rsk_Akt', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'PI3K_Akt', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Akt_Akt', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'C3G_Akt', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Rap1_Akt', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'bRaf_Akt', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Sos_C3G', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Ras_C3G', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Raf1_C3G', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Mek_C3G', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Erk_C3G', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'P90Rsk_C3G', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'PI3K_C3G', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Akt_C3G', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'C3G_C3G', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Rap1_C3G', -0.050765837112266454, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'bRaf_C3G', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Sos_Rap1', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Ras_Rap1', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Raf1_Rap1', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Mek_Rap1', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Erk_Rap1', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'P90Rsk_Rap1', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'PI3K_Rap1', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Akt_Rap1', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'C3G_Rap1', 0.406359660544056, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Rap1_Rap1', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'bRaf_Rap1', -0.6010557464608827, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Sos_bRaf', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Ras_bRaf', 0.39398948380804044, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Raf1_bRaf', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Mek_bRaf', -0.012624957623473043, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Erk_bRaf', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'P90Rsk_bRaf', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'PI3K_bRaf', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Akt_bRaf', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'C3G_bRaf', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'Rap1_bRaf', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
# ['WT_RAS', 'bRaf_bRaf', 0.0, 0.5, 250, 0.1052734375, 19, 13, 'MRA', 'WT:wt_ras', 0, 'NO_THETA', 0.005773529547997323]
